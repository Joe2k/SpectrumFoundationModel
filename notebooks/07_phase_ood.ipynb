# %% [markdown]
# # Phase 7 — OOD evaluation
#
# Hold out healpix tiles via healpix_split(seed=42); evaluate on val manifest.

# %%
import sys
from pathlib import Path
sys.path.insert(0, '../src')
from desifm.data.dr1_stream import healpix_split, load_manifest
# records = load_manifest(Path('manifest.jsonl'))
# train, val = healpix_split(records)
print('Use 5% healpix holdout — see dr1_stream.healpix_split')
