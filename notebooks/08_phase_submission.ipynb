# %% [markdown]
# # Phase 8 — Submission figures
#
# Aggregate W&B runs (project desi-fm-2026) and export plots for report.

# %%
print('W&B project: desi-fm-2026')
print('Registry: ../TRAINING_REGISTRY.yaml')
print('Log: ../RESEARCH_LOG.md')
