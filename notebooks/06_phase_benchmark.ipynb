# %% [markdown]
# # Phase 6 — Benchmark export
#
# Compare TF z accuracy vs FoundationModel baseline (~73.8% Approach A).

# %%
import json
from pathlib import Path
p = Path('../checkpoints/smoke_local/smoke_approach_a/metrics.jsonl')
if p.exists():
    rows=[json.loads(l) for l in p.open()]
    print('last train', rows[-1])
else:
    print('Train with train_model.py then read metrics.jsonl')
