# %% [markdown]
# # Phase 4 — Approach A (joint redshift head)
#
# Encoder sees z; auxiliary z_head on pooled encoder output.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from desifm.training.batching import build_sequences
import torch
B,T=2,16
spec=torch.randint(0,512,(B,T))
z=torch.randint(0,32,(B,))
enc,dec,tgt,mp=build_sequences(spec,z,'a',encoder_mask_ratio=0.5)
print('enc',enc.shape,'dec',dec.shape,'tgt',tgt.shape)
