# %% [markdown]
# # Phase 5 — Approach B (REDMASK decoder)
#
# Decoder position 1 is always REDMASK; no z in encoder.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'src'))
from desifm.constants import REDMASK
from desifm.training.batching import build_sequences
import torch
enc,dec,tgt,_=build_sequences(torch.randint(0,512,(2,16)),torch.randint(0,32,(2,)),'b')
print('decoder[1] unique', dec[:,1].unique().tolist(), 'REDMASK=', REDMASK)
